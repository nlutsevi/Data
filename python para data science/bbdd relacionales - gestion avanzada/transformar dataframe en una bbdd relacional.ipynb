# %%
import pandas as pd
data = [(1, "Joan", "Gasul", 25, 1, "Libreta", 1.2, .4,0.8,3, "03-02-2018"),
       (1, "Joan", "Gasul", 25, 2, "Bolígrafo", 0.4, 0.15, 0.25, 1, "03-02-2018"),
       (1, "Joan", "Gasul", 25, 1, "Libreta", 1.2, .4, 0.8, 2, "15-02-2018"),
       (2, "Joan", "Lopez", 33, 2, "Bolígrafo", 0.4, 0.15, 0.25, 4, "01-02-2018"),
       (3, "Maria", "Garcia", 40, 1, "Libreta", 1.2, .4, 0.8, 10, "13-04-2018")]
labels = ["Comprador_id", "Nombre", "Apellido", "Edad", "Producto_id","Producto", "Precio", "Coste", "Margen", "Cantidad", "Fecha"]

# %%
df = pd.DataFrame.from_records(data, columns = labels)

# %%
df
# Out:
#    Comprador_id Nombre Apellido  Edad  Producto_id   Producto  Precio  Coste  \
# 0             1   Joan    Gasul    25            1    Libreta     1.2   0.40
# 1             1   Joan    Gasul    25            2  Bolígrafo     0.4   0.15
# 2             1   Joan    Gasul    25            1    Libreta     1.2   0.40
# 3             2   Joan    Lopez    33            2  Bolígrafo     0.4   0.15
# 4             3  Maria   Garcia    40            1    Libreta     1.2   0.40
#
#    Margen  Cantidad       Fecha
# 0    0.80         3  03-02-2018
# 1    0.25         1  03-02-2018
# 2    0.80         2  15-02-2018
# 3    0.25         4  01-02-2018
# 4    0.80        10  13-04-2018

# %%
compradores = df.drop_duplicates(subset = "Comprador_id", keep = "first")

# %%
compradores
# Out:
#    Comprador_id Nombre Apellido  Edad  Producto_id   Producto  Precio  Coste  \
# 0             1   Joan    Gasul    25            1    Libreta     1.2   0.40
# 3             2   Joan    Lopez    33            2  Bolígrafo     0.4   0.15
# 4             3  Maria   Garcia    40            1    Libreta     1.2   0.40
#
#    Margen  Cantidad       Fecha
# 0    0.80         3  03-02-2018
# 3    0.25         4  01-02-2018
# 4    0.80        10  13-04-2018

# %%
compradores = compradores[["Comprador_id", "Nombre", "Apellido", "Edad"]]

# %%
compradores
# Out:
#    Comprador_id Nombre Apellido  Edad
# 0             1   Joan    Gasul    25
# 3             2   Joan    Lopez    33
# 4             3  Maria   Garcia    40

# %%
productos = df.drop_duplicates(subset = "Producto_id", keep = "first")

# %%
productos
# Out:
#    Comprador_id Nombre Apellido  Edad  Producto_id   Producto  Precio  Coste  \
# 0             1   Joan    Gasul    25            1    Libreta     1.2   0.40
# 1             1   Joan    Gasul    25            2  Bolígrafo     0.4   0.15
#
#    Margen  Cantidad       Fecha
# 0    0.80         3  03-02-2018
# 1    0.25         1  03-02-2018

# %%
productos = productos[["Producto_id", "Producto", "Precio", "Coste", "Margen"]]

# %%
productos
# Out:
#    Producto_id   Producto  Precio  Coste  Margen
# 0            1    Libreta     1.2   0.40    0.80
# 1            2  Bolígrafo     0.4   0.15    0.25

# %%
compras = df[["Comprador_id", "Producto_id", "Fecha", "Cantidad"]]
compras
# Out:
#    Comprador_id  Producto_id       Fecha  Cantidad
# 0             1            1  03-02-2018         3
# 1             1            2  03-02-2018         1
# 2             1            1  15-02-2018         2
# 3             2            2  01-02-2018         4
# 4             3            1  13-04-2018        10
